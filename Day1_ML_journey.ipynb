# %%
print("hello world")
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# Create a SparkSession
spark = SparkSession.builder.appName("MySparkApp").getOrCreate()



# Sample Data
data = [(1, "Alice"), (2, "Bob"), (3, "Charlie"), (4, "David"), (5, "Eve")]
columns = ["ID", "Name"]
# Create DataFrame
df = spark.createDataFrame(data, columns)
# Show DataFrame
df.show()
# Out:
# hello world
# +---+-------+
# | ID|   Name|
# +---+-------+
# |  1|  Alice|
# |  2|    Bob|
# |  3|Charlie|
# |  4|  David|
# |  5|    Eve|
# +---+-------+

# %%
s={1,2,10,3,3,6,"dev"}
print(s)
# Out:
# {1, 2, 3, 6, 'dev', 10}

# %%
std={"name":"alice","age":20,"grade":"A"}
print(std)

std.update({"city":"newyork"})
print(std)
# Out:
# {'name': 'alice', 'age': 20, 'grade': 'A'}
# {'name': 'alice', 'age': 20, 'grade': 'A', 'city': 'newyork'}

# %%
txt="the quick brown fox jumps over lazy the lazy dog"
sp=txt.split()
print(sp)

l1=[]
l2=[]
for i in sp:
    if i not in l1:
        l1.append(i)
        l2.append(sp.count(i))
print(l1)
print(l2)

d1={}
for i in range(len(l1)):
    d1[l1[i]]=l2[i]
print(d1)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'lazy', 'the', 'lazy', 'dog']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'lazy', 'dog']
# [2, 1, 1, 1, 1, 1, 2, 1]
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 2, 'dog': 1}

# %%
def word_frequency(text):
    words = text.lower().split()
    frequency = {}
    for word in words:
        frequency[word] = frequency.get(word, 0) + 1
    return frequency



def dictb(str) :
  st=str.lower().split()
  d2={}
  for i in st:
    d2[i]=d2.get(i,0)+1
  return d2


txt = "the quick brown fox jumps over the lazy dog"
S1=txt.upper().split()
print(S1)
result = word_frequency(txt)
print(result)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1}

# %%
#Mini Project- Student database

#1 create student database
def std_db():
   database={}
   return database

#add new student to database
def add_std(database):
  usn=input("enter the student USN Number:")
  name=input("enter student name:")
  major=input("enter std dept:")
  database[usn]={"name":name,"major":major}
  print("student added successfully")

#retrive student info
def find_std_info(database):
  std_id=input("enter the student USN Number:")
  std_info=database.get(std_id)
  if std_info:
    print(database.get(std_id))
  else:
    print("student not found")

#print content of database
def display_db(database):
  if database:
    print("student database:")
    print(database)
  else:
    print("database is empty")

#delete std
def del_std(database):
   std_id=input("enter the student USN Number:")
   if std_id in database:
     del database[std_id]
     print("student deleted successfully")
   else:
     print("student not found")

#main program
std_database=std_db()

while True:
  print("options")
  print("1. Add student")
  print("2. find student")
  print("3. display DB")
  print("4. delete std")
  print("5. exit")
  choice=int(input("enter your choice:"))

  if choice==1:
    add_std(std_database)
  elif choice==2:
    find_std_info(std_database)
  elif choice==3:
    display_db(std_database)
  elif choice==4:
    del_std(std_database)
  elif choice==5:
    break
  else:
    print("invalid input, please try again")
# Out:
# options
# 1. Add student
# 2. find student
# 3. display DB
# 4. delete std
# 5. exit
# enter your choice:4
# enter the student USN Number:100
# student not found
# options
# 1. Add student
# 2. find student
# 3. display DB
# 4. delete std
# 5. exit
# enter your choice:5
